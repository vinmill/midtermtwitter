# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
dfin = pd.read_csv('tweets.csv')

# %%
dfin[dfin.quotedTweet.isnull()]
# Out:
#        index                   Datetime             Tweet Id  \
# 0          0  2022-09-30 18:50:14+00:00  1575920975170138113
# 1          1  2022-09-28 23:27:31+00:00  1575265982792220672
# 2          2  2022-09-28 16:24:42+00:00  1575159577536090114
# 3          3  2022-09-27 19:17:10+00:00  1574840590587629614
# 4          4  2022-09-27 19:17:10+00:00  1574840589564219414
# ...      ...                        ...                  ...
# 64057    251  2022-01-30 23:15:03+00:00  1487927367259627523
# 64058    252  2022-01-30 22:34:14+00:00  1487917097522978820
# 64059    253  2022-01-30 14:59:36+00:00  1487802684669575168
# 64060    254  2022-01-29 19:12:26+00:00  1487503922235379712
# 64061    255  2022-01-27 09:00:12+00:00  1486625074522337281
#
#                                                     Text       Username  \
# 0      The left is trying to force their radical agen...  SenRonJohnson
# 1      Even Biden’s DEA Administrator Anne Milgram ag...  SenRonJohnson
# ...
